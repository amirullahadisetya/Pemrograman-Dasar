# %% [markdown]
# <a href="https://colab.research.google.com/github/amirullahadisetya/Pemrograman-Dasar/blob/main/Tugas%20Pertemuan%20Pengganti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SOAL 1: Menampilkan Biodata Lengkap

def Biodata():
    """Menampilkan biodata lengkap."""
    print("===BIODATA PRAKTIKAN===")
    print()
    print("Nama        : Amirullah Adi Setya Wicaksana")
    print("NIM         : 4232401016")
    print("Kelas       : RPE-3A")
    print("Jurusan     : Teknik Elektro")

# Pemanggilan
Biodata()
# Out:
# ===BIODATA PRAKTIKAN===
#
# Nama        : Amirullah Adi Setya Wicaksana
# NIM         : 4232401016
# Kelas       : RPE-3A
# Jurusan     : Teknik Elektro

# %%
# SOAL 2: Menghitung Volume Balok

def hitung_volume_balok(panjang, lebar, tinggi):
    """Menghitung volume balok dari panjang, lebar, dan tinggi."""
    return panjang * lebar * tinggi

# Pemanggilan:
p = 4
l = 3
t = 2
print(f"Volume balok dengan panjang {p}, lebar {l}, dan tinggi {t} adalah: {hitung_volume_balok(p, l, t)}")
# Out:
# Volume balok dengan panjang 4, lebar 3, dan tinggi 2 adalah: 24

# %%
# SOAL 3: Menghitung Rata-rata dari List Nilai

def hitung_rata_rata(data_nilai):
    """Menghitung rata-rata dari list angka menggunakan perulangan for."""
    total = 0
    jumlah_valid = 0  # untuk menghitung jumlah nilai yang valid

    # Perulangan untuk menjumlahkan nilai
    for nilai in data_nilai:
        # Pengecekan nilai valid (antara 0 dan 100)
        if 0 <= nilai <= 100:
            total += nilai
            jumlah_valid += 1
        else:
            print(f"Nilai {nilai} tidak valid dan diabaikan.")

    # Pembagian untuk rata-rata
    if jumlah_valid > 0:
        return total / jumlah_valid
    return 0


# Pemanggilan:
nilai_praktikan = [85, 78, 92, 65, 90]
print(f"Nilai rata-rata kelas adalah: {hitung_rata_rata(nilai_praktikan)}")
# Out:
# Nilai rata-rata kelas adalah: 82.0

# %%
# SOAL 4: Sistem Penentuan Predikat Nilai (dengan pengecekan tipe data)

def tentukan_predikat(skor):
    """Menentukan predikat (A, B, C, D, E) berdasarkan skor.
    Hanya menerima input numerik (int atau float)."""

    # Pengecekan tipe data
    if not isinstance(skor, (int, float)):
        return "Input tidak valid! Skor harus berupa angka."

    # Pengecekan rentang nilai
    if skor < 0 or skor > 100:
        return "Skor di luar rentang! Harus antara 0 dan 100."

    # Penentuan predikat berdasarkan skor
    if skor >= 85:
        return "A"
    elif skor >= 75:
        return "B"
    elif skor >= 60:
        return "C"
    elif skor >= 50:
        return "D"
    else:
        return "E"


# Pemanggilan:
print(f"Skor 75 mendapat predikat: {tentukan_predikat(75)}")
print(f"Skor 48 mendapat predikat: {tentukan_predikat(48)}")
print(f"Skor 'A' mendapat predikat: {tentukan_predikat('A')}")
print(f"Skor 120 mendapat predikat: {tentukan_predikat(120)}")
# Out:
# Skor 75 mendapat predikat: B
# Skor 48 mendapat predikat: E
# Skor 'A' mendapat predikat: Input tidak valid! Skor harus berupa angka.
# Skor 120 mendapat predikat: Skor di luar rentang! Harus antara 0 dan 100.

# %%
# SOAL 5: Menghitung Faktorial dengan Loop While

def hitung_faktorial(n):
    """Menghitung faktorial dari bilangan positif n."""

    # Penanganan kasus khusus
    if n < 0:
        return "Error: Faktorial tidak dapat dihitung untuk bilangan negatif."
    elif n == 0:
        return 1  # Secara matematis, 0! = 1

    hasil = 1

    # Perulangan berjalan selama n lebih besar dari 1
    while n > 1:
        hasil *= n
        n -= 1  # Kurangi n setiap iterasi

    return hasil

# Pemanggilan:
bilangan_n = 4
print(f"Faktorial dari {bilangan_n} adalah: {hitung_faktorial(bilangan_n)}")  # Output: 24
print(f"Faktorial dari 0 adalah: {hitung_faktorial(0)}")                      # Output: 1
print(f"Faktorial dari -3 adalah: {hitung_faktorial(-3)}")                    # Output: Error
# Out:
# Faktorial dari 4 adalah: 24
# Faktorial dari 0 adalah: 1
# Faktorial dari -3 adalah: Error: Faktorial tidak dapat dihitung untuk bilangan negatif.

# %%
# SOAL 6: Analisis Data Suhu Ekstrem (for dan if/elif)

def analisis_suhu(data_suhu, batas_panas=35, batas_dingin=15):
    """Menghitung jumlah hari Panas dan Dingin dari data_suhu."""
    panas_count = 0
    dingin_count = 0

    for suhu in data_suhu:
        if suhu >= batas_panas:
            panas_count += 1
        elif suhu <= batas_dingin:
            dingin_count += 1

    return panas_count, dingin_count

# Pemanggilan:
suhu_mingguan = [36, 30, 14, 25, 38, 16, 28]
jumlah_panas, jumlah_dingin = analisis_suhu(suhu_mingguan)
print(f"Jumlah hari Panas (>=35°C): {jumlah_panas}")
print(f"Jumlah hari Dingin (<=15°C): {jumlah_dingin}")
# Out:
# Jumlah hari Panas (>=35°C): 2
# Jumlah hari Dingin (<=15°C): 1
