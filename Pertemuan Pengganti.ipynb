# %% [markdown]
# <a href="https://colab.research.google.com/github/amirullahadisetya/Pemrograman-Dasar/blob/main/Pertemuan%20Pengganti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mendefinisikan fungsi
def sapa(nama):
    return f"Halo, {nama}!"

# Menggunakan fungsi
print(sapa("Andi"))
print(sapa("Budi"))
print(sapa("Citra"))
# Out:
# Halo, Andi!
# Halo, Budi!
# Halo, Citra!

# %%
# Fungsi dengan beberapa parameter
def hitung_total(harga, jumlah):
    return harga * jumlah

def hitung_diskon(total, persen_diskon):
    return total * (persen_diskon / 100)

# Penggunaan fungsi
harga_barang = 5000
jumlah_barang = 3

total = hitung_total(harga_barang, jumlah_barang)
diskon = hitung_diskon(total, 10)

print(f"Total: Rp{total}")
print(f"Diskon: Rp{diskon}")
print(f"Bayar: Rp{total - diskon}")
# Out:
# Total: Rp15000
# Diskon: Rp1500.0
# Bayar: Rp13500.0

# %%
def kalkulator():
    # TODO: Minta input angka pertama dari user
    angka1 = input("Masukkan angka pertama: ")
    angka2 = input("Masukkan angka kedua: ")

    angka1 = int(angka1)
    angka2 = int(angka2)

    hasil = angka1 + angka2

    return hasil

hasil = kalkulator()
print(f"Hasil penjumlahan: {hasil}")

# Alternatif untuk testing tanpa input:
def test_kalkulator():
    return 10 + 5

print(f"Test: 10 + 5 = {test_kalkulator()}")
# Out:
# Masukkan angka pertama: 1
# Masukkan angka kedua: 2
# Hasil penjumlahan: 3
# Test: 10 + 5 = 15

# %%
def hitung_rata_rata(a, b, c):
    total = a + b + c
    return total / 3

def format_nilai(nama, nilai):
    if nilai >= 80:
        grade = "A"
    elif nilai >= 70:
        grade = "B"
    else:
        grade = "C"
    return f"{nama}: {nilai} ({grade})"

result1 = hitung_rata_rata(85, 90, 75)
result2 = format_nilai("Andi", result1)
print(result2)
# Out:
# Andi: 83.33333333333333 (A)

# %%
def proses_data(numbers):
    hasil = []
    for num in numbers:
        if num % 2 == 0:
            hasil.append(num * 2)
        else:
            hasil.append(num + 10)
    return hasil

def hitung_total(data_list):
    return sum(data_list)

input_data = [2, 3, 4, 5]
step1 = proses_data(input_data)
step2 = hitung_total(step1)
print(f"Hasil akhir: {step2}")
# Out:
# Hasil akhir: 40

# %%
# Sistem pemesanan minuman

def hitung_total(menu_pesanan):
    total = 0
    for nama, harga in menu_pesanan:
        total += harga
    return total

def hitung_diskon(total):
    if total > 50000:
        return total * 0.1
    return 0

def tampilkan_ringkasan(nama, menu, total, diskon):
    print(f"Pesanan untuk: {nama}")
    for i, (nama_minuman, harga) in enumerate(menu, 1):
        print(f"{i}. {nama_minuman} - Rp{harga}")
    print(f"Total: Rp{total}")
    print(f"Diskon: Rp{diskon}")
    print(f"Harga Final: Rp{total - diskon}")

# Contoh penggunaan
menu = [
    ("Es Teh Manis", 8000),
    ("Kopi Susu", 18000),
    ("Jus Mangga", 20000)
]

total = hitung_total(menu)
diskon = hitung_diskon(total)
tampilkan_ringkasan("Rani", menu, total, diskon)
# Out:
# Pesanan untuk: Rani
# 1. Es Teh Manis - Rp8000
# 2. Kopi Susu - Rp18000
# 3. Jus Mangga - Rp20000
# Total: Rp46000
# Diskon: Rp0
# Harga Final: Rp46000
